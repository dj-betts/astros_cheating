# %%
# class BabeballReference:
#     def __init__(self):

# %%
driver = webdriver.Chrome()
driver.get('https://www.baseball-reference.com/teams/tgl.cgi?team=HOU&t=b&year=2017')
sleep(2)

# %%
html = driver.page_source
# Out:
# '<html data-version="klecko-" data-root="/home/br/deploy/www" itemscope="" itemtype="https://schema.org/WebSite" lang="en" class=" js cookies localstorage sessionstorage cors history csspositionsticky no-touchevents pointerevents matchmedia flexwrap desktop is_live overthrow-enabled" style=""><head><script type="text/javascript" async="" src="https://static.criteo.net/js/ld/publishertag.prebid.js"></script><script async="" type="text/javascript" src="https://a.pub.network/core/pubfig/pubfig.messaging.2.1.2.js"></script><script src="https://rules.quantcount.com/rules-p-UeXruRVtZz7w6.js" async=""></script><script src="https://tagan.adlightning.com/freestar/bl-04a3385-be610303.js" type="text/javascript" defer=""></script><script src="https://tagan.adlightning.com/freestar/b-9a4f7ce-5d02a085.js" type="text/javascript" defer=""></script><script type="text/javascript"></script>\n    <script async="" type="text/javascript" src="https://sb.scorecardresearch.com/beacon.js"></script><script as
# ...

# %%
driver.title
# Out:
# '2017 Houston Astros Batting Game Logs | Baseball-Reference.com'
